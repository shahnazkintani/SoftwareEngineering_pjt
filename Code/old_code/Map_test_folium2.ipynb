# %%
import folium
from folium import plugins
import pandas as pd
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
gis_project = pd.read_csv('C:\\Users\\AyG\\Documents\\Software engineering\\go_t.csv')

# %%
gis_project.head()
# Out:
#     id   latitude  longitude  track_id            time
# 0  aaa -10.939341 -37.062742         1  9/13/2014 7:24
# 1  aaa -10.939341 -37.062742         1  9/13/2014 7:24
# 2  aaa -10.939324 -37.062765         1  9/13/2014 7:24
# 3  aaa -10.939211 -37.062843         1  9/13/2014 7:24
# 4  aaa -10.938939 -37.062879         1  9/13/2014 7:24

# %%
m = folium.Map([-10.939341, -37.062742], zoom_start=11)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
for index, row in gis_project.iterrows():
    folium.CircleMarker([row['latitude'], row['longitude']],
                        radius=5,
                        popup=row['id']
                       ).add_to(m)

# %%
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
